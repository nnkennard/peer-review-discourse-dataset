# %%
# Imports

import collections
import json
import logging
import tqdm

logging.basicConfig(filename="example2.log")
logger = logging.getLogger()
logger.setLevel(logging.DEBUG)

# Constants for later

REVIEW_ID, INITIALS = "review_id initials".split()
REVIEW, REBUTTAL, METADATA = "review rebuttal metadata".split()

class AnnotationTypes(object):
    rev_ann = "reviewannotation"
    rev_sent_ann = "reviewsentenceannotation"
    reb_sent_ann = "rebuttalsentenceannotation"
    ALL = [rev_ann, rev_sent_ann, reb_sent_ann]

with open('annomap.json', 'r') as f:
    ANONYMIZER = json.load(f)
    
TYPE_TO_KEY_MAP = {
    AnnotationTypes.rev_sent_ann: "review_sentence_index",
    AnnotationTypes.reb_sent_ann: "rebuttal_sentence_index",
}
    
preferred_annotators = ["anno{0}".format(i) for i in range(20)] # Fix this!!

# Set up text data structures

META_FIELDS_TO_EXTRACT = 'forum_id review_id rebuttal_id title reviewer'.split()

def metadata_formatter(fields):
    metadata = {k:v for k,v in fields.items() if k in META_FIELDS_TO_EXTRACT}
    if fields["dataset"].startswith("traindev"):
        metadata["conference"] = "ICLR2019"
    else:
        metadata["conference"] = "ICLR2020"
    metadata["permalink"] = "https://openreview.net/forum?id={0}&noteId={1}".format(
        metadata["forum_id"], metadata["rebuttal_id"])
    return metadata

with open("final_data_dump/orda_text_0415.json", 'r') as f:
    j = json.load(f)
    
sentence_map = collections.defaultdict(list)
for sentence in j["sentence"]:
    fields = sentence["fields"]
    assert fields["sentence_index"] == len(
        sentence_map[fields["comment_id"]])
    sentence_map[fields["comment_id"]].append(fields["text"])
    
    
comment_pair_map = {}    
for example in j["example"]:
    fields = example["fields"]
    review_id, rebuttal_id = fields["review_id"], fields["rebuttal_id"]
    comment_pair_map[review_id] = {
        REVIEW: sentence_map[review_id],
        REBUTTAL: sentence_map[rebuttal_id],
        METADATA: metadata_formatter(fields)
    }
 
# Collect annotations

class AnnotationCollector(object):
    def __init__(self, review_id, annotator):
        self.review_id = review_id
        self.annotator = annotator
        self.annotations = {annotation_type: [] for annotation_type in AnnotationTypes.ALL}
    
    def is_valid(self):
        if self.review_id == 'example_review':
            logging.info("Skipping example review annotated by {0}".format(self.annotator))
            return False
        for annotation_type, annotation_list in self.annotations.items():
            if not annotation_list:
                logging.info("{0} {1} missing {2}".format(self.review_id, self.annotator, annotation_type))
                return False
        return True
    
    def __repr__(self):
        return "\n".join(["Annotation collector for {0} annotated by {1}".format(self.review_id, self.annotator)]
                         + ["{0} : {1}".format(ann_type, len(anns)) for ann_type, anns in self.annotations.items()]+ [""])
    
def get_key_from_annotation(ann):
    return ann["fields"][REVIEW_ID], ANONYMIZER[ann["fields"][INITIALS]]
    
with open("final_data_dump/orda_annotations_0516.json", 'r') as f:
    annotations_from_file = json.load(f) 

annotation_collectors = collections.defaultdict(dict)

for annot in AnnotationTypes.ALL:
    sorted_rows = sorted(
        annotations_from_file[annot], key=lambda x:x["pk"])
    for row in sorted_rows:
        rev_id, annotator  = get_key_from_annotation(row)
        if annotator not in annotation_collectors[rev_id]:
            annotation_collectors[rev_id][annotator] = AnnotationCollector(rev_id, annotator)
        annotation_collectors[rev_id][annotator].annotations[annot].append(row)
            

# def get_merge_prev(error_field):
#     if type(error_field) == dict:
#         return error_field["merge_prev"]
#     elif type(error_field) == str:
#         error_field = json.loads(error_field)
#         return get_merge_prev(error_field)
#     else:
#         assert False

# ReviewSentenceLabels = collections.namedtuple("ReviewSentenceLabels", 
#                                               "review_id sentence_index coarse fine aspect polarity".split())

                
def clean_review_sentence_dict(rev_sent_dict):
    print(rev_sent_dict)
    new_map = {}
    for k, v in rev_sent_dict["fields"].items():
        if k == "labels":
            labels = json.loads(json.loads(v))
            new_map.update(labels["0"])
        else:
            new_map[k] = v
    return new_map

def filter_annotations_for_latest(annotation_collection, annotation_type):
    final_annotations = {}
    key = TYPE_TO_KEY_MAP[annotation_type]
    for annotation in sorted(annotation_collection.annotations[annotation_type], key=lambda x:x["pk"]):
        final_annotations[annotation["fields"][key]] = annotation
    final_list = [final_annotations[k] for k in sorted(final_annotations.keys())]
    return final_list

ReviewSentence = collections.namedtuple("ReviewSentence",
                                          "review_id sentence_index text coarse fine asp pol".split())
RebuttalSentence = collections.namedtuple("RebuttalSentence",
                "review_id rebuttal_id sentence_index text coarse fine alignment alignment_type".split())

class Annotation(object):
    def __init__(self, review_sentences, rebuttal_sentences, meta):
        self.meta = meta
        self.review_sentences = review_sentences
        self.rebuttal_sentences = rebuttal_sentences
        
    def __repr__(self):
        return json.dumps(
        {
            "metadata": self.meta,
            "review_sentences": [sent._asdict() for sent in self.review_sentences],
            "rebuttal_sentences": [sent._asdict() for sent in self.rebuttal_sentences]
            
        })

def get_review_sentences(annotation_collection, review_text, merge_prev):
    final_review_sentences = []
    filtered_sentences = filter_annotations_for_latest(annotation_collection, AnnotationTypes.rev_sent_ann)
    review_id = None 
    print(len(merge_prev) - len(filtered_sentences))
    for sentence in filtered_sentences:
        index = sentence["fields"]["review_sentence_index"]
        labels = clean_review_sentence_dict(sentence)
        print(review_text[index])
        print(labels)
    print()
    return None, None

def get_rebuttal_sentences(annotation_collection, rebuttal_text):
    final_rebuttal_sentences = []
    review_id = None # fix
    rebuttal_id = None # fix
    for sentence in filter_annotations_for_latest(annotation_collection, AnnotationTypes.reb_sent_ann):
        index = sentence["fields"]["rebuttal_sentence_index"]
        aligned_indices = [i for i, val in enumerate(sentence["fields"]["aligned_review_sentences"]) if val]
        final_rebuttal_sentences.append(RebuttalSentence(
            review_id, rebuttal_id, index, rebuttal_text[index],
            None, sentence["fields"]["relation_label"], aligned_indices, sentence["fields"]["alignment_category"]))
    return final_rebuttal_sentences




def build_annotation(annotation_collection, text_and_metadata, other_annotators=[]):
    metadata = text_and_metadata[METADATA]
    metadata["annotator"] = annotation_collection.annotator
    metadata["other_annotators"] = other_annotators

    merge_prev = json.loads(
        annotation_collection.annotations[AnnotationTypes.rev_ann][0]["fields"]["errors"])["merge_prev"]
    review_sentences, _  = get_review_sentences(annotation_collection,
                                                           text_and_metadata[REVIEW], merge_prev)
    rebuttal_sentences = get_rebuttal_sentences(annotation_collection,
                                                           text_and_metadata[REBUTTAL])
    return Annotation(metadata, review_sentences, rebuttal_sentences)



def pick_best_annotation(valid_annotations):
    for best_annotator in preferred_annotators:
        if best_annotator in valid_annotations:
            return (valid_annotations[best_annotator],
                    [annotation
                     for annotator, annotation in valid_annotations.items()
                     if not annotator == best_annotator])
    assert False # Iterating through all possible annotators, we should never reach here.
    
extra_annotation_list = [] 
final_annotation_list = [] 
    
for review_id, collector_dict in tqdm.tqdm(annotation_collectors.items()):
    valid_annotations = {collector.annotator: collector
                         for collector in collector_dict.values() if collector.is_valid()}
    if valid_annotations:
        main_annotation, other_annotations = pick_best_annotation(valid_annotations)
        final_annotation_list.append(build_annotation(main_annotation, comment_pair_map[review_id], [oa.annotator for oa in other_annotations]))
        extra_annotation_list += [build_annotation(extra_annotation, comment_pair_map[review_id]) for extra_annotation in other_annotations]
# Out:
#   2%|▏         | 8/455 [00:00<00:01, 352.69it/s]
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 10317, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper is about using "neural stethoscopes", small complementary neural networks that are added to a main network which with their auxilary loss functions can measure suitability of features or guide the learning process.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10318, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# The idea is incremental to multi-task learning and enable, in a single framework, to validate intermediate features for additional related tasks.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10319, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Fact\\"},\\"1\\":{}}"'}}
# Moreover it can promote or suppress the correlation of such features to the tasks related to the main one.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Fact'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10320, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The framework is applied to the task of visual stability prediction of block towers.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10321, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 4, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper builds upon Groth et al. 2018, adding the concept of local stability as correlated secondary task, used with the proposed neural stethoscopes.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 4, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10322, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 5, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# Experiments with an extension of ShapeStacks (Groth et al. 2018) dataset where the local stability is added to the global stability class, show that it is possibile increase the performance using the additional task.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 5, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10323, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 6, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Moreover, it is shown that neural stethoscopes can suppress nuisance information when using a biased training dataset where the local and global stability are purposely inversely correlated.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 6, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10324, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 7, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Strengths:
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 7, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10325, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 8, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + A very nice paper, well written and easy to read. Figures are helpful and the structure is clear.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 8, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10326, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 9, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + The concept of neural stethoscope is interesting and simplify the concepts behind multitask learning.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 9, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10327, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 10, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + Experiments are convincing, interesting and there is some novelty in vision stability prediction.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 10, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10328, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 11, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Weaknesses:
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 11, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10329, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 12, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - The novelty is limited related to multitask learning, thus it is an incremental paper.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 12, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 3521, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 0, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper is about using "neural stethoscopes", small complementary neural networks that are added to a main network which with their auxilary loss functions can measure suitability of features or guide the learning process.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 0, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3522, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 1, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The idea is incremental to multi-task learning and enable, in a single framework, to validate intermediate features for additional related tasks.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 1, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3523, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 2, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Moreover it can promote or suppress the correlation of such features to the tasks related to the main one.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 2, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3524, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 3, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The framework is applied to the task of visual stability prediction of block towers.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 3, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3525, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 4, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper builds upon Groth et al. 2018, adding the concept of local stability as correlated secondary task, used with the proposed neural stethoscopes.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 4, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3526, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 5, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Experiments with an extension of ShapeStacks (Groth et al. 2018) dataset where the local stability is added to the global stability class, show that it is possibile increase the performance using the additional task.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 5, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3527, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 6, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Moreover, it is shown that neural stethoscopes can suppress nuisance information when using a biased training dataset where the local and global stability are purposely inversely correlated.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 6, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3528, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 7, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Strengths:
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 7, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3529, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 8, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + A very nice paper, well written and easy to read. Figures are helpful and the structure is clear.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 8, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3530, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 9, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + The concept of neural stethoscope is interesting and simplify the concepts behind multitask learning.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 9, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3531, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 10, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# + Experiments are convincing, interesting and there is some novelty in vision stability prediction.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 10, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3532, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 11, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Weaknesses:
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 11, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3533, 'fields': {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 12, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - The novelty is limited related to multitask learning, thus it is an incremental paper.
# {'review_id': 'rJgLrhZq2X', 'review_sentence_index': 12, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 10309, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper focuses on the stability prediction task on the ShapeStacks dataset.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10310, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Specifically, the paper creates a new extension to the dataset, and it proposes the use of "Neural Stethoscopes" framework to analyze deep neural nets' physical reasoning of local stability v.s. global stability.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10311, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# It is shown in the paper neural nets tend to be misled by local stability when the task is to predict global stability.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10312, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Then the paper utilizes the proposed framework to de-bias the misleading correlation to achieve a state-of-the-art on the dataset.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10313, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 4, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# The paper is very well-written and easy to follow.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 4, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10314, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 5, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# The main idea is simple and the experiments are detailed.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 5, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10315, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 6, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# Specifically on the task of stability prediction, it is quite interesting to know that neural nets can be misled by visual cues (local stability).
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 6, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 10316, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 7, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# However, my concern is that the paper focuses only on a very specific application domain,  and an improvement over the niche dataset with much more supervision (from the extension) is not surprising at all. In the mean time, the notion of "Neural Stethoscopes" could be much more  generally applied. Without applications in other domains, it is not immediately clear what the paper's implication is.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 7, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 3534, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 0, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper focuses on the stability prediction task on the ShapeStacks dataset.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 0, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3535, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 1, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Specifically, the paper creates a new extension to the dataset, and it proposes the use of "Neural Stethoscopes" framework to analyze deep neural nets' physical reasoning of local stability v.s. global stability.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 1, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3536, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 2, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# It is shown in the paper neural nets tend to be misled by local stability when the task is to predict global stability.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 2, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3537, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 3, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Then the paper utilizes the proposed framework to de-bias the misleading correlation to achieve a state-of-the-art on the dataset.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 3, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3538, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 4, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# The paper is very well-written and easy to follow.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 4, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3539, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 5, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# The main idea is simple and the experiments are detailed.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 5, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3540, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 6, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Other\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# Specifically on the task of stability prediction, it is quite interesting to know that neural nets can be misled by visual cues (local stability).
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 6, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Other', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3541, 'fields': {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 7, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"}}"'}}
# However, my concern is that the paper focuses only on a very specific application domain,  and an improvement over the niche dataset with much more supervision (from the extension) is not surprising at all. In the mean time, the notion of "Neural Stethoscopes" could be much more  generally applied. Without applications in other domains, it is not immediately clear what the paper's implication is.
# {'review_id': 'B1lChPhJpQ', 'review_sentence_index': 7, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 4149, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper provides some insights on influence of data distribution on robustness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4150, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper demonstrates through a number of analysis that the distance between the training an test data sets plays an important role on the effectiveness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4151, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# To show the latter, the paper proposes an approach to measure the distance between the two data sets using combination of nonlinear projection (e.g. t-SNE), KDE, and K-L divergence.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4152, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper also shows that under simple transformation to the test dataset (e.g. scaling), performance of adversarial training reduces significantly due to the large gap between training and test data set.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4153, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 4, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This tends to impact high dimensional data sets more than low dimensional data sets since it is much harder to cover the whole ground truth data distribution in the training dataset.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 4, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4154, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 5, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Pros:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 5, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4155, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 6, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# - Provides insights on why adversarial training is less effective on some datasets.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 6, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4156, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 7, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# - Proposes a metric that seems to strongly correlate with the effectiveness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 7, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4157, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 8, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Cons:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 8, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4158, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 9, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - Lack of theoretical analysis. It could have been nice if the authors could show the observed phenomenon analytically on some simple distribution.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 9, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4159, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 10, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - The marketing phrase "the blind-spot attach" falls short in delivering what one may expect from the paper after reading it.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 10, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4160, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 11, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# The paper would read much better if the authors better describe the phenomena based on the gap between the two distribution than using bling-spot.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 11, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4161, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 12, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Fact\\"},\\"1\\":{}}"'}}
# For some dataset, this is beyond a spot, it could actually be huge portion of the input space!
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 12, 'initials': 'TJO', 'arg': 'Fact'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4162, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 13, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Minor comments:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 13, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4163, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 14, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Meaningful Comparison\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - I believe one should not compare the distance shown between the left and right columns of Figure 3 as they are obtained from two different models.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 14, 'initials': 'TJO', 'arg': 'Request', 'req': 'Edit', 'asp': 'Meaningful Comparison', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4164, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 15, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# Though the paper is not suggesting that, it would help to clarify it in the paper.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 15, 'initials': 'TJO', 'arg': 'Request', 'req': 'Edit', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4165, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 16, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Explanation\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# Furthermore, it would help if the paper elaborates why the distance between the test and training dataset is smaller in an adversarially trained network compared to a naturally trained network.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 16, 'initials': 'TJO', 'arg': 'Request', 'req': 'Explanation', 'asp': 'Substance', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4166, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 17, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Clarification\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# - Are the results in Table 1 for an adversarially trained network or a naturally trained network?
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 17, 'initials': 'TJO', 'arg': 'Request', 'req': 'Clarification', 'asp': 'Replicability', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4167, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 18, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Experiment\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# Either way, it could be also interesting to see the average K-L divergence between an adversarially and a naturally trained network on the same dataset.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 18, 'initials': 'TJO', 'arg': 'Request', 'req': 'Experiment', 'asp': 'Replicability', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 4168, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 19, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# - Please provide more visualization similarly to those shown in Fig 4.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 19, 'initials': 'TJO', 'arg': 'Request', 'req': 'Edit', 'asp': 'Clarity', 'pol': 'U-Neutral'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 82, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 0, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper provides some insights on influence of data distribution on robustness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 0, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 83, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 1, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper demonstrates through a number of analysis that the distance between the training an test data sets plays an important role on the effectiveness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 1, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 84, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 2, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# To show the latter, the paper proposes an approach to measure the distance between the two data sets using combination of nonlinear projection (e.g. t-SNE), KDE, and K-L divergence.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 2, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 85, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 3, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# The paper also shows that under simple transformation to the test dataset (e.g. scaling), performance of adversarial training reduces significantly due to the large gap between training and test data set.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 3, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 86, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 4, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This tends to impact high dimensional data sets more than low dimensional data sets since it is much harder to cover the whole ground truth data distribution in the training dataset.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 4, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 87, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 5, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Pros:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 5, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 88, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 6, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# - Provides insights on why adversarial training is less effective on some datasets.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 6, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 89, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 7, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# - Proposes a metric that seems to strongly correlate with the effectiveness of adversarial training.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 7, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 90, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 8, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Cons:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 8, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 91, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 9, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - Lack of theoretical analysis. It could have been nice if the authors could show the observed phenomenon analytically on some simple distribution.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 9, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 92, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 10, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - The marketing phrase "the blind-spot attach" falls short in delivering what one may expect from the paper after reading it.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 10, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 93, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 11, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# The paper would read much better if the authors better describe the phenomena based on the gap between the two distribution than using bling-spot.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 11, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 94, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 12, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Fact\\"},\\"1\\":{}}"'}}
# For some dataset, this is beyond a spot, it could actually be huge portion of the input space!
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 12, 'initials': 'MC', 'arg': 'Fact'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 95, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 13, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Minor comments:
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 13, 'initials': 'MC', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 96, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 14, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - I believe one should not compare the distance shown between the left and right columns of Figure 3 as they are obtained from two different models.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 14, 'initials': 'MC', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 97, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 15, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# Though the paper is not suggesting that, it would help to clarify it in the paper.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 15, 'initials': 'MC', 'arg': 'Request', 'req': 'Edit', 'asp': 'Clarity', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 98, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 16, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# Furthermore, it would help if the paper elaborates why the distance between the test and training dataset is smaller in an adversarially trained network compared to a naturally trained network.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 16, 'initials': 'MC', 'arg': 'Request', 'req': 'Edit', 'asp': 'Clarity', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 99, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 17, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Clarification\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# - Are the results in Table 1 for an adversarially trained network or a naturally trained network?
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 17, 'initials': 'MC', 'arg': 'Request', 'req': 'Clarification', 'asp': 'Clarity', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 100, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 18, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Fact\\"},\\"1\\":{}}"'}}
# Either way, it could be also interesting to see the average K-L divergence between an adversarially and a naturally trained network on the same dataset.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 18, 'initials': 'MC', 'arg': 'Fact'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 101, 'fields': {'review_id': 'Hygsieas2X', 'review_sentence_index': 19, 'initials': 'MC', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Edit\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# - Please provide more visualization similarly to those shown in Fig 4.
# {'review_id': 'Hygsieas2X', 'review_sentence_index': 19, 'initials': 'MC', 'arg': 'Request', 'req': 'Edit', 'asp': 'Clarity', 'pol': 'U-Neutral'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 102, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper combines the global and local stability prediction and tries to get interpretable results using the stethoscope design, which is actually a weighted subbranch for the main branch.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 103, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# There are several concerns regarding the proposed framework.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 104, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Clarification\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# 1) How to choose \lambda?
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Request', 'req': 'Clarification', 'asp': 'Replicability', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 105, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# A better design could be a learnable \lambda.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 106, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 4, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Experiment\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# Instead of just one scalar value, it could be better to learn a map of \lambdas, which indicates the distribution of local stability and how it is related to global stability.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 4, 'initials': 'TJO', 'arg': 'Request', 'req': 'Experiment', 'asp': 'Substance', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 107, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 5, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Experiment\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"U-Neutral\\"},\\"1\\":{}}"'}}
# The visualization of the \lambda map might be more interpretable for understanding the stability prediction.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 5, 'initials': 'TJO', 'arg': 'Request', 'req': 'Experiment', 'asp': 'Substance', 'pol': 'U-Neutral'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 108, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 6, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# 2) The global stability prediction does not have a consistent correlation with the local stability prediction, as shown by the easy and hard examples.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 6, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 109, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 7, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Fact\\"},\\"1\\":{}}"'}}
# This complex relationship will confuse the network during the training.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 7, 'initials': 'TJO', 'arg': 'Fact'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 110, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 8, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# That is, the current design hasn't well considered the local and global stability relation, but just simply sum them up.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 8, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 111, 'fields': {'review_id': 'SklxtSc93Q', 'review_sentence_index': 9, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# This is hard to provide a meaningful interpretation of the task.
# {'review_id': 'SklxtSc93Q', 'review_sentence_index': 9, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 11427, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# Summary: This paper introduces a new Neural Network training procedure, designed for tabular data, that seeks to leverage feature clusters extracted from GBDTs.
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11428, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# Strengths: The idea of leveraging feature groups in a neural network structure; the novelty of the RESE model;
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11429, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# Weaknesses: The main weakness of the paper is that the performance gains are extremely low compared to the next contender; perhaps they are statistically significant (this cannot be determined), but it's unclear why we wouldn't use GBDT.
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11430, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Minor typos:
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# ...
# - "NN has achieved" => "Neural Networks have achieved"
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 5, 'initials': 'MAD', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3898, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 6, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - "performances" => performance
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 6, 'initials': 'MAD', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3899, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 7, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - "explicitly leverages" => "explicitly leverage"
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 7, 'initials': 'MAD', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3900, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 8, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Questions:
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 8, 'initials': 'MAD', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3901, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 9, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Explanation\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - (top of p. 2) What exactly is the difference between "implicit feature combinations" and "explicit (?), expressive feature combinations"
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 9, 'initials': 'MAD', 'arg': 'Request', 'req': 'Explanation', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3902, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 10, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Explanation\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - (top of p. 2) "encourage parameter sharing" - between what and what? at which level? [reading on, I realized this applies to groups of features; it should maybe be made clear earlier]
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 10, 'initials': 'MAD', 'arg': 'Request', 'req': 'Explanation', 'asp': 'Clarity', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3903, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 11, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Explanation\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# - what is the benefit brought by the 'Structural Knowledge' transfer? is this quantified anywhere? based on the description, I don't understand if this is an add-on to TabNN or whether it is incorporated in TabNN.
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 11, 'initials': 'MAD', 'arg': 'Request', 'req': 'Explanation', 'asp': 'Replicability', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 3904, 'fields': {'review_id': 'HkeGURdb6X', 'review_sentence_index': 12, 'initials': 'MAD', 'labels': '"{\\"0\\":{\\"arg\\":\\"Request\\",\\"req\\":\\"Experiment\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# Recommendations for the authors: Would it be possible to provide an analysis of the cases when TabNN is expected to outperform GBDT by a sizable margin? Or, if not, are there other reasons why using a neural network would make more sense than just simply running GBDT?
# {'review_id': 'HkeGURdb6X', 'review_sentence_index': 12, 'initials': 'MAD', 'arg': 'Request', 'req': 'Experiment', 'asp': 'Substance', 'pol': 'N-Negative'}
#
# 0
# {'model': 'orda.reviewsentenceannotation', 'pk': 11440, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 0, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Summary\\"},\\"1\\":{}}"'}}
# This paper proposes a hybrid machine learning algorithm using Gradient Boosted Decision Trees (GBDT) and Deep Neural Networks (DNN).
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 0, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Summary'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11441, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 1, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# The intended research direction on tabular data is essential and promising.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 1, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11442, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 2, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# However, the proposed technique does not seem to be handling the problem foundationally well.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 2, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11443, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 3, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# It seems heavily dependent on GBDT.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 3, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Replicability', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11444, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 4, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# It also shows itself in the results that final algorithm is almost indistinguishable from GBDT regarding results.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 4, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11445, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 5, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Replicability\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# Moreover, I  don't think that the data sets in experiments are good enough to cover the importance and the nature of the problem.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 5, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Replicability', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11446, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 6, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Pros:
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 6, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11447, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 7, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Motivation/Impact\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# -This is a crucial line of research direction that aims to make DNNs applicable to many real-world problems (beyond speech and vision) in which discrete data and heterogeneous features exist such as engagement prediction, recommendation, and search.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 7, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Motivation/Impact', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11448, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 8, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# -The starting point of using GBDT seems like a good choice.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 8, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11449, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 9, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Clarity\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# -The Paper is mostly well written except occasional repetitions and missing acronym definitions.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 9, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Clarity', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11450, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 10, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Structuring\\",\\"struc\\":\\"Heading\\"},\\"1\\":{}}"'}}
# Cons:
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 10, 'initials': 'TJO', 'arg': 'Structuring', 'struc': 'Heading'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11451, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 11, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# -The proposed technique does not seem to be original enough, and it does not handle the problem foundationally well.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 11, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11452, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 12, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# I do not think that there is enough justification/demonstration for the fact that a general NN solution for Tabular Data invented.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 12, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11453, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 13, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# The proposed technique is heavily dependent on GBDT (Indeed the algorithm and the learned trees are used at least three times).
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 13, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11454, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 14, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# This shows itself in the results; i.e., the proposed algorithm is either negligibly performing better than GBDT or when  GBDT dependence removed, it performs worse. It seems to me
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 14, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11455, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 15, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Originality\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# that (except the minor small section of streaming data), the paper is more like a proper verification of how tree-based learning algorithms work very well in tabular data--which is far from the basis of the paper and does not make the paper novel enough for ICLR.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 15, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Originality', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11456, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 16, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Soundness/Correctness\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# -The proposed technique seems to include very heavy feature engineering and several ad-hoc practical steps--that is far from the motivation of using NN in tabular data.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 16, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Soundness/Correctness', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11457, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 17, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"P-Positive\\"},\\"1\\":{}}"'}}
# -In the provided benchmark data sets the depth of the analysis seems to be enough.
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 17, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'P-Positive'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11458, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 18, 'initials': 'TJO', 'labels': '"{\\"0\\":{\\"arg\\":\\"Evaluative\\",\\"asp\\":\\"Substance\\",\\"pol\\":\\"N-Negative\\"},\\"1\\":{}}"'}}
# However, in the proposed domain of tabular data, often data sets are significantly more high dimensional in reality and include at least one set of sparse large dimensional features
# {'review_id': 'SJgssoHT27', 'review_sentence_index': 18, 'initials': 'TJO', 'arg': 'Evaluative', 'asp': 'Substance', 'pol': 'N-Negative'}
# {'model': 'orda.reviewsentenceannotation', 'pk': 11459, 'fields': {'review_id': 'SJgssoHT27', 'review_sentence_index': 19, 'initials': 'TJO', 'labels': '"{}"'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-666f7f95e19e> in <module>
#     218     if valid_annotations:
#     219         main_annotation, other_annotations = pick_best_annotation(valid_annotations)
# --> 220         final_annotation_list.append(build_annotation(main_annotation, comment_pair_map[review_id], [oa.annotator for oa in other_annotations]))
#     221         extra_annotation_list += [build_annotation(extra_annotation, comment_pair_map[review_id]) for extra_annotation in other_annotations]
#
# <ipython-input-1-666f7f95e19e> in build_annotation(annotation_collection, text_and_metadata, other_annotators)
#     193     merge_prev = json.loads(
#     194         annotation_collection.annotations[AnnotationTypes.rev_ann][0]["fields"]["errors"])["merge_prev"]
# --> 195     review_sentences, _  = get_review_sentences(annotation_collection,
#     196                                                            text_and_metadata[REVIEW], merge_prev)
#     197     rebuttal_sentences = get_rebuttal_sentences(annotation_collection,
#
# <ipython-input-1-666f7f95e19e> in get_review_sentences(annotation_collection, review_text, merge_prev)
#     165     for sentence in filtered_sentences:
#     166         index = sentence["fields"]["review_sentence_index"]
# --> 167         labels = clean_review_sentence_dict(sentence)
#     168         print(review_text[index])
#     169         print(labels)
#
# <ipython-input-1-666f7f95e19e> in clean_review_sentence_dict(rev_sent_dict)
#     125         if k == "labels":
#     126             labels = json.loads(json.loads(v))
# --> 127             new_map.update(labels["0"])
#     128         else:
#     129             new_map[k] = v
#
# KeyError: '0'
